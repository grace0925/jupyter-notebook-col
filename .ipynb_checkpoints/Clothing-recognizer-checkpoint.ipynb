# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# # Clothing-Item-Recognizer

# %% [markdown]
# #### Importing fashion datasets

# %%
import tensorflow as tf
from tensorflow import keras

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.fashion_mnist
type(mnist)
# Out:
# module

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
np.max(x_train)
# Out:
# 255

# %%
np.mean(x_train)
# Out:
# 72.94035223214286

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
class_names = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %% [markdown]
# #### Data exploration

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
plt.figure()
plt.imshow(x_train[1])
plt.colorbar()

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
x_train = x_train/255.0

# %%
x_test = x_test/255.0

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()

# %% [markdown]
# #### Build model with TF

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %% [markdown]
# Flatten layer transforms data from two dimensional into one dimensional.
# Frist Dense layer states how many neurons(nodes) we want to pass in, and the activation function.
# Second Dense layer output layer, define how many outputs there are (10 because of 10 types of clothings).

# %%
model = Sequential()
model.add(Flatten(input_shape = (28,28)))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Model compilation

# %% [markdown]
# - Loss function (measure how accurate the model is during training and testing; minimizes error during training)
# - Optimizer (how model updates based on data
# - Metrics

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.4964 - accuracy: 0.8254
# Epoch 2/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8654 ETA: 2s - loss: 0.3 - E - 3s 46us/sample - loss: 0.3719 - accuracy: 0.8657
# Epoch 3/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.87 - 3s 46us/sample - loss: 0.3352 - accuracy: 0.8768
# Epoch 4/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.8864 ETA - 3s 45us/sample - loss: 0.3118 - accuracy: 0.8862
# Epoch 5/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2941 - accuracy: 0.8909
# Epoch 6/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2785 - accuracy: 0.8977s - l - ETA: 1s - loss: 0.2779 - accuracy - ETA:
# Epoch 7/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2680 - accuracy: 0.9005
# Epoch 8/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.9041 ETA: 2s - loss: 0.2515 - accura - - 3s 46us/sample - loss: 0.2575 - accuracy: 0.9041
# Epoch 9/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2475 - accuracy: 0.9072 0s - loss: 0.2469 - accura
# Epoch 10/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.2393 - accuracy: 0.9091s - loss: 0.2399 - accuracy

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.8807

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict_classes(x_test)

# %%
y_pred
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8807

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array([[1.6730009e-07, 1.3151794e-10, 5.2301301e-09, ..., 1.3608417e-02,
#         1.4467209e-08, 9.8621690e-01],
#        [1.5810529e-05, 2.3500597e-11, 9.9655354e-01, ..., 2.2125465e-14,
#         8.8239638e-11, 3.1186824e-12],
#        [4.1164165e-09, 1.0000000e+00, 1.0930492e-13, ..., 1.6438233e-22,
#         1.4673110e-13, 3.2526028e-21],
#        ...,
#        [5.4923043e-05, 5.2867671e-12, 4.5312441e-05, ..., 1.1891757e-07,
#         9.9938452e-01, 4.5351299e-13],
#        [3.2772054e-08, 9.9998522e-01, 3.8698411e-10, ..., 1.2466393e-16,
#         1.7688158e-09, 1.2326744e-13],
#        [1.7763743e-06, 2.8867930e-08, 2.4334495e-06, ..., 5.0091473e-03,
#         3.9289979e-04, 4.2277901e-05]], dtype=float32)

# %%
np.argmax(pred[0])
# Out:
# 9
